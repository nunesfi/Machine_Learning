# %% [markdown]
# ## Gráficos

# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv('/home/nunesfi/Desktop/IA/files/AirPassengers.csv')
dataset
# Out:
#        Month  #Passengers
# 0    1949-01          112
# 1    1949-02          118
# 2    1949-03          132
# 3    1949-04          129
# 4    1949-05          121
# ..       ...          ...
# 139  1960-08          606
# 140  1960-09          508
# 141  1960-10          461
# 142  1960-11          390
# 143  1960-12          432
#
# [144 rows x 2 columns]

# %%
dataset.plot()
# Out:
# <Axes: >

# %%
dataset.set_index("Month").plot()
# Out:
# <Axes: xlabel='Month'>

# %%
dataset.set_index("Month").loc["1949-01":"1949-12"].plot()
# Out:
# <Axes: xlabel='Month'>

# %% [markdown]
# ## Formatação

# %%
#Incluindo indice no plot
dataset.set_index("Month").loc["1949-01":"1949-12"].plot(title="Voos em 1949",
                                                        xlabel="Data",
                                                        ylabel="Quantidade",
                                                        color="red",
                                                        style="-.",
                                                        legend=True).legend(loc = "best")

# %%
import seaborn as sns
sns.set_style("darkgrid")

# %%
dataset.set_index("Month").loc["1949-01":"1949-12"].plot(title="Voos em 1949",
                                                        xlabel="Data",
                                                        ylabel="Quantidade",
                                                        color="red",
                                                        style="-.",
                                                        legend=True).legend(loc = "best")

# %% [markdown]
# ## Subgráficos

# %%
dataset = pd.read_csv('/home/nunesfi/Desktop/IA/files/census.csv')

# %%
#fazendo grafico para cada tópico
dataset.plot(subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >],
#       dtype=object)

# %%
dataset.plot(subplots=True, layout=(3,3), figsize= (10,10),
            title= ["Age", "Final-weight", "Education-run", "Capitan-gain", "capital-loos", "hour-per-week"],
            legend=False, kind="hist");

# %% [markdown]
# ## Gráficos - Barra e Pizza

# %%
dataset.workclass.unique()
# Out:
# array([' State-gov', ' Self-emp-not-inc', ' Private', ' Federal-gov',
#        ' Local-gov', ' ?', ' Self-emp-inc', ' Without-pay',
#        ' Never-worked'], dtype=object)

# %%
dataset.groupby("workclass")["age"].count().plot(kind="bar")
# Out:
# <Axes: xlabel='workclass'>

# %%
dataset.groupby("workclass")["age"].count().plot.barh()
# Out:
# <Axes: ylabel='workclass'>

# %%
pivot = dataset.query("workclass != ' Nerver-worked' and workclass != ' Without-pay'").pivot_table(index = "income",
                    columns = "workclass",
                    values = "education-num",
                    aggfunc="sum").apply(lambda x: x*100 / sum(x), axis=1)
pivot
# Out:
# workclass         ?   Federal-gov   Local-gov   Never-worked    Private  \
# income
#  <=50K     6.261205      2.604793      6.5877       0.021935  70.660964
#  >50K           NaN           NaN         NaN            NaN        NaN
#
# workclass   Self-emp-inc   Self-emp-not-inc   State-gov
# income
#  <=50K          2.125173           7.433045    4.305185
#  >50K                NaN                NaN         NaN

# %%
pivot.plot.bar(stacked = True).legend(bbox_to_anchor = (1.4,1))

# %% [markdown]
# # Gráfico de Pizza

# %%
dataset.groupby("workclass")["age"].count().plot.pie(title = "Workclass", ylabel ="")
# Out:
# <Axes: title={'center': 'Workclass'}>

# %% [markdown]
# ## Gráfico de Dispersão

# %%
# relacionamento entre duas colunas numéricas
dataset.columns
# Out:
# Index(['age', 'workclass', 'final-weight', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loos', 'hour-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
dataset.plot.scatter(x = "education-num", y = "capital-gain")
# Out:
# <Axes: xlabel='education-num', ylabel='capital-gain'>

# %%
dataset.plot.scatter(x = "hour-per-week", y = "education-num")
# Out:
# <Axes: xlabel='hour-per-week', ylabel='education-num'>

# %%
dataset.plot.scatter(x = "hour-per-week", y = "capital-gain")
# Out:
# <Axes: xlabel='hour-per-week', ylabel='capital-gain'>

# %% [markdown]
# ## Histograma

# %%
dataset["age"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
dataset["education-num"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
dataset["capital-gain"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
dataset[["age","education-num"]].plot.hist(alpha = 0.4)
# Out:
# <Axes: ylabel='Frequency'>

# %%
plot = dataset.plot.hist(alpha = 0.3)

# %%
#salvar gráfico
plot.figure.savefig("histograma.png")
